# %% [markdown]
# # Exercise "Git/Mercurial"
# Create a public repository for your exercises/homeworks using Git.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Exercise "Git/Mercurial" summary
#
# This exercise was completed using **Git** and **GitHub**.
#
# A public GitHub repository was created for the course work. The repository was named `PPNM` and contains the main course folders:
#
# ```bash
# Exam
# Exercises
# Homework
# Testing
# README.md
