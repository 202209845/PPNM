# %% [markdown]
# # Exercise “Hello, World!”
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Exercise "Hello, World!" summary
#
# This exercise was completed by installing a C++ compiler in the WSL Ubuntu POSIX environment.
#
# The compiler setup was checked with
#
# ```bash
# g++ --version
# make --version

# %% [markdown]
# A simple C++ workflow was then used: write a .cc or .cpp source file, compile it with g++, and run the resulting executable. The same workflow was used throughout the later homework exercises, where C++ source files were generated, compiled, and executed from the notebook/terminal.
#
# A minimal Hello World program has the form:

# %%
#include <iostream>

int main() {
    std::cout << "Hello, World!" << std::endl;
    return 0;
}

# %% [markdown]
# and can be compiled with:

# %%
g++ hello.cc -o hello
./hello

# %% [markdown]
# Thus, the goal of the exercise was fulfilled: a working C++ compiler was installed and the basic compile-and-run workflow was tested successfully.
